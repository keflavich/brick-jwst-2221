# %% [markdown]
# # Build A Reference Catalog
#
# This is just a simple call to make_reftable

# %%
# %run ../analysis/make_reftable.py
# Out:
# QFs are good for 57704 out of 487795 catalog entries
# Rejecting 1463 replaced-saturated sources.
# Rejecting 375 near-saturated sources.
# Making the reference catalog from 55866 out of 487795 catalog entries
# WARNING: VerifyWarning: Keyword name 'PARENT_VERSION' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]

# %%
reftbl
# Out:
# <Table length=55866>
#             skycoord_f410m                         skycoord_f405n             mag_ab_f410m         RA                 DEC
#                deg,deg                                deg,deg                                     deg                 deg
#                SkyCoord                               SkyCoord                  float32         float64             float64
# -------------------------------------- -------------------------------------- ------------ ------------------ -------------------
#  266.5138001154151,-28.747930796496217  266.5137997611741,-28.747927048431137    12.388214  266.5138001154151 -28.747930796496217
#  266.5582577596566,-28.704823443321967  266.5582430459691,-28.704822293787576    12.531346  266.5582577596566 -28.704823443321967
#  266.5128798072241,-28.674406454181245 266.51287114206366,-28.674408722494523    12.766528  266.5128798072241 -28.674406454181245
# ...
